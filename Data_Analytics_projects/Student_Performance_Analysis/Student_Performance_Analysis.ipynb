# %% [markdown]
# # **Project 1: Student Marks Analysis Dashboard (Using Matplotlib & Pandas)**

# %% [markdown]
# ### Project Flow:
#
# 1. Import libraries
# 2. Create dataset
# 3. View dataset
# 4. Basic analysis
# 5. Bar chart
# 6. Line chart
# 7. Pie chart

# %%
# Student Marks Analysis Dashboard
# Beginner Project using Pandas and Matplotlib

print("Student Marks Analysis Dashboard")
# Out:
# Student Marks Analysis Dashboard

# %%
# step 1: Import libraries

# import pandas for table data
import pandas as pd

# import matplotlib for charts
import matplotlib.pyplot as plt

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
# step 2: Create dataset

# create student marks dataset using dictionary

data = {
    "Name": ["Madhu", "Rahul", "Priya", "Arjun", "Neha"],
    "Math": [85, 78, 92, 74, 88],
    "Science": [90, 82, 89, 70, 91],
    "English": [88, 75, 95, 72, 84]
}

# convert dictionary into DataFrame
df = pd.DataFrame(data)

# view DataFrame
df
# Out:
#     Name  Math  Science  English
# 0  Madhu    85       90       88
# 1  Rahul    78       82       75
# 2  Priya    92       89       95
# 3  Arjun    74       70       72
# 4   Neha    88       91       84

# %%
# step 3: View basic dataset info

# show first rows
print("First 5 rows:")
print(df.head())


# show shape
print("\nShape of dataset:")
print(df.shape)


# show column names
print("\nColumns:")
print(df.columns)
# Out:
# First 5 rows:
#     Name  Math  Science  English
# 0  Madhu    85       90       88
# 1  Rahul    78       82       75
# 2  Priya    92       89       95
# 3  Arjun    74       70       72
# 4   Neha    88       91       84
#
# Shape of dataset:
# (5, 4)
#
# Columns:
# Index(['Name', 'Math', 'Science', 'English'], dtype='object')

# %%
# step 4: Add total marks column

# create a new column Total
# add marks of all subjects

df["Total"] = df["Math"] + df["Science"] + df["English"]

df
# Out:
#     Name  Math  Science  English  Total
# 0  Madhu    85       90       88    263
# 1  Rahul    78       82       75    235
# 2  Priya    92       89       95    276
# 3  Arjun    74       70       72    216
# 4   Neha    88       91       84    263

# %%
# step 5: Add average marks column

# create Average column
# divide total by 3 subjects

df["Average"] = df["Total"] / 3

df
# Out:
#     Name  Math  Science  English  Total    Average
# 0  Madhu    85       90       88    263  87.666667
# 1  Rahul    78       82       75    235  78.333333
# 2  Priya    92       89       95    276  92.000000
# 3  Arjun    74       70       72    216  72.000000
# 4   Neha    88       91       84    263  87.666667

# %%
# step 6: Basic analysis

# find highest total marks
print("Highest Total Marks:", df["Total"].max())

# find lowest total marks
print("Lowest Total Marks:", df["Total"].min())

# find average of total marks
print("Average Total Marks:", df["Total"].mean())
# Out:
# Highest Total Marks: 276
# Lowest Total Marks: 216
# Average Total Marks: 250.6

# %%
# step 7: Find topper

# find student with highest total marks
# Pandas library in Python, idxmax() is a method used to find the index label of the first occurrence of the maximum value in a Series or DataFrame

# idxmax() gives index of highest value
# loc[] selects that row

topper = df.loc[df["Total"].idxmax()]

print("Topper Details:")
print(topper)
# Out:
# Topper Details:
# Name       Priya
# Math          92
# Science       89
# English       95
# Total        276
# Average     92.0
# Name: 2, dtype: object

# %%
# step 8: Bar chart

# bar chart for total marks of students

plt.figure(figsize=(8,5))
plt.bar(df["Name"], df["Total"])
plt.title("Total Marks of Students")
plt.xlabel("Student Name")
plt.ylabel("Total Marks")
plt.show()

# %%
# step 9: Line chart

# line chart for average marks of students

plt.figure(figsize=(8,5))
plt.plot(df["Name"], df["Average"], marker="o")
plt.title("Average Marks of Students")
plt.xlabel("Student Name")
plt.ylabel("Average Marks")
plt.show()

# line chart shows trend
# marker="o" shows points clearly

# %%
# step 10: Pie chart

# pie chart for total marks distribution

plt.figure(figsize=(7,7))
plt.pie(df["Total"], labels=df["Name"], autopct="%1.1f%%")
plt.title("Marks Distribution of Students")
plt.show()

# pie chart shows percentage share
# autopct shows percentage on chart

# %%
# step 11: Subject-wise average

# calculate average marks of each subject

subject_avg = {
    "Math": df["Math"].mean(),
    "Science": df["Science"].mean(),
    "English": df["English"].mean()
}

print(subject_avg)
# Out:
# {'Math': np.float64(83.4), 'Science': np.float64(84.4), 'English': np.float64(82.8)}

# %%
# step 12: Bar chart for subject averages

# bar chart of subject average marks

plt.figure(figsize=(8,5))
plt.bar(subject_avg.keys(), subject_avg.values())
plt.title("Average Marks by Subject")
plt.xlabel("Subjects")
plt.ylabel("Average Marks")
plt.show()

# helps students compare subjects
# now chart is subject-wise, not student-wise

# %%
# step 13: Grade column

# create grade based on average marks

grades = []

for avg in df["Average"]:
    if avg >= 90:
        grades.append("A")
    elif avg >= 80:
        grades.append("B")
    elif avg >= 70:
        grades.append("C")
    else:
        grades.append("D")

df["Grade"] = grades

df
# Out:
#     Name  Math  Science  English  Total    Average Grade
# 0  Madhu    85       90       88    263  87.666667     B
# 1  Rahul    78       82       75    235  78.333333     C
# 2  Priya    92       89       95    276  92.000000     A
# 3  Arjun    74       70       72    216  72.000000     C
# 4   Neha    88       91       84    263  87.666667     B

# %%
# step 14: Grade count

# count how many students got each grade

grade_count = df["Grade"].value_counts()

print(grade_count)
# Out:
# Grade
# B    2
# C    2
# A    1
# Name: count, dtype: int64

# %%
# step 15: Pie chart for grade distribution

# pie chart for grade distribution

plt.figure(figsize=(7,7))
plt.pie(grade_count, labels=grade_count.index, autopct="%1.1f%%")
plt.title("Grade Distribution")
plt.show()

# %%
# step 16: Final dataset

# final full dataset

df
# Out:
#     Name  Math  Science  English  Total    Average Grade
# 0  Madhu    85       90       88    263  87.666667     B
# 1  Rahul    78       82       75    235  78.333333     C
# 2  Priya    92       89       95    276  92.000000     A
# 3  Arjun    74       70       72    216  72.000000     C
# 4   Neha    88       91       84    263  87.666667     B

# %%
# what we have learnt

# Final summary

print("Project Completed Successfully")
print("Topics covered:")
print("1. DataFrame creation")
print("2. Basic analysis")
print("3. Adding new columns")
print("4. Bar chart")
print("5. Line chart")
print("6. Pie chart")
print("7. Grade distribution")
# Out:
# Project Completed Successfully
# Topics covered:
# 1. DataFrame creation
# 2. Basic analysis
# 3. Adding new columns
# 4. Bar chart
# 5. Line chart
# 6. Pie chart
# 7. Grade distribution
