# %% [markdown]
# # **Advanced Pandas**

# %% [markdown]
# **Agenda:**
#
# 1. Find repeated values using value_counts()
# 2. Group data using groupby()
# 3. Remove duplicate rows
# 4. Use string methods on text columns
# 5. Use apply() for custom logic
# 6. value_counts()
# 7. unique() and nunique()
# 8. duplicated() and drop_duplicates()
# 9. string methods with .str
# 10. apply()
# 11. map()
# 12. replace()
# 13. filtering with multiple conditions using & and |
# 14. proper use of loc[] and iloc[]
# 15. groupby()
# 16. aggregation with agg()
# 17. sorting by multiple columns
# 18. set_index() and reset_index()
# 19. datetime conversion with to_datetime()
# 20. .dt accessor
# 21. pivot table
# 22. crosstab()
# 23. concat()
# 24. merge()
# 25. join()
# 26. reading Excel files
# 27. exporting cleaned data
# 28. basic plotting with pandas
# 29. basic EDA workflow

# %%
# Pandas: value_counts()

# value_counts() counts repeated values
# very useful for categories like department, city, grade, gender

import pandas as pd

# Create simple student data
data = {
    "Name": ["Ali", "Sara", "John", "Ali", "Sara", "Ali"],
    "Department": ["CSE", "CSE", "ECE", "CSE", "ECE", "CSE"],
    "Marks": [85, 90, 78, 88, 91, 95]
}

df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

# Count how many times each name appears
print("\nCount of each student name:")
print(df["Name"].value_counts())

# Count how many students are in each department
print("\nCount of each department:")
print(df["Department"].value_counts())

# %%
# Pandas: groupby()

# groupby() means make groups
# here we grouped students by department
# then found average marks of each group

import pandas as pd

data = {
    "Name": ["Ali", "Sara", "John", "David", "Emma"],
    "Department": ["CSE", "CSE", "ECE", "ECE", "CSE"],
    "Marks": [85, 90, 78, 88, 91]
}

df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

# Group by department and find average marks
grouped = df.groupby("Department")["Marks"].mean()

print("\nAverage marks department-wise:")
print(grouped)

# %%
# Pandas: Remove duplicates

# duplicated() shows True for repeated rows
# drop_duplicates() removes repeated rows

import pandas as pd

data = {
    "Name": ["Ali", "Sara", "Ali", "John", "Sara"],
    "Marks": [85, 90, 85, 78, 90]
}

df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

# Check duplicate rows
print("\nDuplicate rows:")
print(df.duplicated())

# Remove duplicate rows
df_no_duplicates = df.drop_duplicates()

print("\nDataFrame after removing duplicates:")
print(df_no_duplicates)

# %%
# Pandas: String operations

# .str.upper() → uppercase
# .str.title() → first letter capital
# .str.len() → length of text

import pandas as pd

data = {
    "Name": ["ali", "sara", "john", "david"],
    "City": ["kolkata", "delhi", "mumbai", "chennai"]
}

df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

# Convert names to uppercase
df["Name_Upper"] = df["Name"].str.upper()

# Convert city names to title case
df["City_Title"] = df["City"].str.title()

# Find length of each name
df["Name_Length"] = df["Name"].str.len()

print("\nAfter string operations:")
print(df)

# %%
# Pandas: apply()

# apply() is used when built-in functions are not enough
# we created our own function and applied it to each mark

import pandas as pd

data = {
    "Name": ["Ali", "Sara", "John", "David"],
    "Marks": [85, 42, 78, 33]
}

df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

# Function to assign pass/fail
def check_result(mark):
    if mark >= 40:
        return "Pass"
    else:
        return "Fail"

# Apply function on Marks column
df["Result"] = df["Marks"].apply(check_result)

print("\nDataFrame after apply():")
print(df)

# %%
# unique() and nunique()

import pandas as pd

data = {
    "City": ["Kolkata", "Delhi", "Mumbai", "Delhi", "Kolkata", "Chennai"]
}

df = pd.DataFrame(data)

print(df)

# Show unique values
print(df["City"].unique())

# Count number of unique values
print(df["City"].nunique())

# %%
# map()

import pandas as pd

data = {
    "Name": ["Ali", "Sara", "John"],
    "Grade": ["A", "B", "C"]
}

df = pd.DataFrame(data)

print(df)

# Map grades to remarks
remarks = {
    "A": "Excellent",
    "B": "Good",
    "C": "Average"
}

df["Remark"] = df["Grade"].map(remarks)

print(df)

# %%
# replace()

import pandas as pd

data = {
    "Name": ["Ali", "Sara", "John"],
    "Department": ["CS", "IT", "CS"]
}

df = pd.DataFrame(data)

print(df)

# Replace old values with new values
df["Department"] = df["Department"].replace("CS", "CSE")

print(df)

# %%
# filtering with multiple conditions using & and |

import pandas as pd

data = {
    "Name": ["Ali", "Sara", "John", "David"],
    "Marks": [85, 35, 60, 28],
    "Department": ["CSE", "ECE", "CSE", "EEE"]
}

df = pd.DataFrame(data)

print(df)

# AND condition
print(df[(df["Marks"] > 40) & (df["Department"] == "CSE")])

# OR condition
print(df[(df["Marks"] > 80) | (df["Department"] == "EEE")])
# Out:
#     Name  Marks Department
# 0    Ali     85        CSE
# 1   Sara     35        ECE
# 2   John     60        CSE
# 3  David     28        EEE
#    Name  Marks Department
# 0   Ali     85        CSE
# 2  John     60        CSE
#     Name  Marks Department
# 0    Ali     85        CSE
# 3  David     28        EEE

# %%
# proper use of loc[] and iloc[] (Row Select)

import pandas as pd

data = {
    "Name": ["Ali", "Sara", "John", "David"],
    "Marks": [85, 90, 78, 88],
    "Department": ["CSE", "ECE", "EEE", "CSE"]
}

df = pd.DataFrame(data)

print(df)

# loc[] uses label names
print(df.loc[0])                  # first row
print(df.loc[1:2, ["Name", "Marks"]])   # selected rows and columns

# iloc[] uses index positions
print(df.iloc[0])                 # first row
print(df.iloc[1:3, 0:2])          # rows 1 to 2, columns 0 to 1
# Out:
#     Name  Marks Department
# 0    Ali     85        CSE
# 1   Sara     90        ECE
# 2   John     78        EEE
# 3  David     88        CSE
# Name          Ali
# Marks          85
# Department    CSE
# Name: 0, dtype: object
#    Name  Marks
# 1  Sara     90
# 2  John     78
# Name          Ali
# Marks          85
# Department    CSE
# Name: 0, dtype: object
#    Name  Marks
# 1  Sara     90
# 2  John     78

# %%
# aggregation with agg()

import pandas as pd

data = {
    "Department": ["CSE", "CSE", "ECE", "ECE", "CSE"],
    "Marks": [85, 90, 78, 88, 91]
}

df = pd.DataFrame(data)

print(df)

# Multiple aggregations
print(df.groupby("Department")["Marks"].agg(["mean", "max", "min", "sum"]))
# Out:
#   Department  Marks
# 0        CSE     85
# 1        CSE     90
# 2        ECE     78
# 3        ECE     88
# 4        CSE     91
#                  mean  max  min  sum
# Department
# CSE         88.666667   91   85  266
# ECE         83.000000   88   78  166

# %%
# sorting by multiple columns

import pandas as pd

data = {
    "Name": ["Ali", "Sara", "John", "David"],
    "Department": ["CSE", "CSE", "ECE", "ECE"],
    "Marks": [85, 90, 90, 78]
}

df = pd.DataFrame(data)

print(df)

# Sort by Department first, then Marks descending
sorted_df = df.sort_values(by=["Department", "Marks"], ascending=[True, False])

print(sorted_df)
# Out:
#     Name Department  Marks
# 0    Ali        CSE     85
# 1   Sara        CSE     90
# 2   John        ECE     90
# 3  David        ECE     78
#     Name Department  Marks
# 1   Sara        CSE     90
# 0    Ali        CSE     85
# 2   John        ECE     90
# 3  David        ECE     78

# %%
# set_index() and reset_index()

import pandas as pd

data = {
    "Roll": [101, 102, 103],
    "Name": ["Ali", "Sara", "John"],
    "Marks": [85, 90, 78]
}

df = pd.DataFrame(data)

print(df)

# Set Roll as index
df2 = df.set_index("Roll")
print(df2)

# Reset index back to normal
df3 = df2.reset_index()
print(df3)
# Out:
#    Roll  Name  Marks
# 0   101   Ali     85
# 1   102  Sara     90
# 2   103  John     78
#       Name  Marks
# Roll
# 101    Ali     85
# 102   Sara     90
# 103   John     78
#    Roll  Name  Marks
# 0   101   Ali     85
# 1   102  Sara     90
# 2   103  John     78

# %%
# datetime conversion with to_datetime()

import pandas as pd

data = {
    "Name": ["Ali", "Sara", "John"],
    "Join_Date": ["2024-01-15", "2024-02-10", "2024-03-20"]
}

df = pd.DataFrame(data)

print(df)

# Convert string date into datetime format
df["Join_Date"] = pd.to_datetime(df["Join_Date"])

print(df)
print(df.dtypes)
# Out:
#    Name   Join_Date
# 0   Ali  2024-01-15
# 1  Sara  2024-02-10
# 2  John  2024-03-20
#    Name  Join_Date
# 0   Ali 2024-01-15
# 1  Sara 2024-02-10
# 2  John 2024-03-20
# Name                 object
# Join_Date    datetime64[ns]
# dtype: object

# %%
# .dt accessor

import pandas as pd

data = {
    "Name": ["Ali", "Sara", "John"],
    "Join_Date": ["2024-01-15", "2024-02-10", "2024-03-20"]
}

df = pd.DataFrame(data)

df["Join_Date"] = pd.to_datetime(df["Join_Date"])

# Extract year, month, day
df["Year"] = df["Join_Date"].dt.year
df["Month"] = df["Join_Date"].dt.month
df["Day"] = df["Join_Date"].dt.day

print(df)
# Out:
#    Name  Join_Date  Year  Month  Day
# 0   Ali 2024-01-15  2024      1   15
# 1  Sara 2024-02-10  2024      2   10
# 2  John 2024-03-20  2024      3   20

# %%
# pivot table

import pandas as pd

data = {
    "Department": ["CSE", "CSE", "ECE", "ECE", "CSE"],
    "Gender": ["Male", "Female", "Male", "Female", "Male"],
    "Marks": [85, 90, 78, 88, 91]
}

df = pd.DataFrame(data)

print(df)

# Create pivot table
pivot = df.pivot_table(values="Marks", index="Department", columns="Gender", aggfunc="mean")

print(pivot)
# Out:
#   Department  Gender  Marks
# 0        CSE    Male     85
# 1        CSE  Female     90
# 2        ECE    Male     78
# 3        ECE  Female     88
# 4        CSE    Male     91
# Gender      Female  Male
# Department
# CSE           90.0  88.0
# ECE           88.0  78.0

# %%
# crosstab()

import pandas as pd

data = {
    "Department": ["CSE", "CSE", "ECE", "ECE", "CSE"],
    "Gender": ["Male", "Female", "Male", "Female", "Male"]
}

df = pd.DataFrame(data)

print(df)

# Frequency table
table = pd.crosstab(df["Department"], df["Gender"])

print(table)
# Out:
#   Department  Gender
# 0        CSE    Male
# 1        CSE  Female
# 2        ECE    Male
# 3        ECE  Female
# 4        CSE    Male
# Gender      Female  Male
# Department
# CSE              1     2
# ECE              1     1

# %%
# concat()

import pandas as pd

df1 = pd.DataFrame({
    "Name": ["Ali", "Sara"],
    "Marks": [85, 90]
})

df2 = pd.DataFrame({
    "Name": ["John", "David"],
    "Marks": [78, 88]
})

print(df1)
print(df2)

# Combine rows
result = pd.concat([df1, df2])

print(result)
# Out:
#    Name  Marks
# 0   Ali     85
# 1  Sara     90
#     Name  Marks
# 0   John     78
# 1  David     88
#     Name  Marks
# 0    Ali     85
# 1   Sara     90
# 0   John     78
# 1  David     88

# %%
# merge()

import pandas as pd

students = pd.DataFrame({
    "ID": [1, 2, 3],
    "Name": ["Ali", "Sara", "John"]
})

marks = pd.DataFrame({
    "ID": [1, 2, 3],
    "Marks": [85, 90, 78]
})

print(students)
print(marks)

# Merge using common column
result = pd.merge(students, marks, on="ID")

print(result)
# Out:
#    ID  Name
# 0   1   Ali
# 1   2  Sara
# 2   3  John
#    ID  Marks
# 0   1     85
# 1   2     90
# 2   3     78
#    ID  Name  Marks
# 0   1   Ali     85
# 1   2  Sara     90
# 2   3  John     78

# %%
# join()

import pandas as pd

df1 = pd.DataFrame({
    "Name": ["Ali", "Sara", "John"]
}, index=[1, 2, 3])

df2 = pd.DataFrame({
    "Marks": [85, 90, 78]
}, index=[1, 2, 3])

print(df1)
print(df2)

# Join based on index
result = df1.join(df2)

print(result)
# Out:
#    Name
# 1   Ali
# 2  Sara
# 3  John
#    Marks
# 1     85
# 2     90
# 3     78
#    Name  Marks
# 1   Ali     85
# 2  Sara     90
# 3  John     78

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-37e8bff7-0f58-4587-ad6b-501cbfdf20ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-37e8bff7-0f58-4587-ad6b-501cbfdf20ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# reading Excel files

import pandas as pd

# Read Excel file
# Make sure openpyxl is installed if needed
df = pd.read_excel("fsi-2015.xlsx")

print(df)
# Out:
#                        Country       Year   Rank  Total  \
# 0                  South Sudan 2015-01-01    1st  114.5
# 1                      Somalia 2015-01-01    2nd  114.0
# 2     Central African Republic 2015-01-01    3rd  111.9
# 3                        Sudan 2015-01-01    4th  110.8
# 4    Congo Democratic Republic 2015-01-01    5th  109.7
# ..                         ...        ...    ...    ...
# 173                 Luxembourg 2015-01-01  174th   22.1
# 174                    Denmark 2015-01-01  175th   21.4
# 175                     Norway 2015-01-01  176th   20.9
# 176                     Sweden 2015-01-01  177th   20.2
# 177                    Finland 2015-01-01  178th   17.7
#
#      C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 0                      10.0                      10.0                 10.0
# 1                       9.7                      10.0                  9.5
# ...

# %%
# exporting cleaned data

import pandas as pd

data = {
    "Name": ["Madhu", "Sara", "John"],
    "Marks": [85, 90, 78]
}

df = pd.DataFrame(data)

# Save as CSV
df.to_csv("cleaned_data_madhu.csv", index=False)

print("File saved successfully")
# Out:
# File saved successfully

# %%
# basic plotting with pandas

import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Name": ["Ali", "Sara", "John", "David"],
    "Marks": [85, 90, 78, 88]
}

df = pd.DataFrame(data)

# Bar plot
df.plot(x="Name", y="Marks", kind="bar")

plt.title("Student Marks")
plt.xlabel("Name")
plt.ylabel("Marks")
plt.show()

# %%
# basic EDA workflow

import pandas as pd

data = {
    "Name": ["Ali", "Sara", "John", "David", "Sara"],
    "Department": ["CSE", "CSE", "ECE", "EEE", "CSE"],
    "Marks": [85, 90, None, 78, 90]
}

df = pd.DataFrame(data)

# 1. View first rows
print(df.head())

# 2. Check data types and missing values
print(df.info())

# 3. Statistical summary
print(df.describe())

# 4. Check missing values
print(df.isnull().sum())

# 5. Fill missing values
df["Marks"] = df["Marks"].fillna(df["Marks"].mean())

# 6. Check duplicate rows
print(df.duplicated().sum())

# 7. Remove duplicates
df = df.drop_duplicates()

# 8. Count departments
print(df["Department"].value_counts())

# 9. Group by department
print(df.groupby("Department")["Marks"].mean())

# 10. Final cleaned data
print(df)
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     90
# 2   John     78
# 3  David     88

# %% [markdown]
# **PANDAS COMPLETED**
